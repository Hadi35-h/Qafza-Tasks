# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\hadi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv("artifacts/LabeledTable.csv")
print(f"Size of data is : {df.shape}")
# Out:
# Size of data is : (96476, 16)

# %%
#تقسم البيانات الموجودة في الجدول السابق الى ثلاث اقسام تدريب و اختبار و تحقق  والتأكد من نسبة الطلبات المتأخرة في كل موجموعة 
# %قسم الاختبار هو 15  
# %قسم اتحقق هو 15  
# %قسم التدريب 70    


train_val_df , test_df = train_test_split(
    df , test_size=0.15 , random_state=42 , stratify=df["is_late"]  # 15% for test , 85% for train & validation , و تقسبم عشوائي  وقايل للتكراري مع المحاقظة على تقسم الفئات 0\1
)
train_df , val_df = train_test_split(
    train_val_df,
    test_size=0.1765,    #                    15%  / 85%           %وهي  15% من 85         
    random_state=42,
    stratify=train_val_df["is_late"],
)
print(f"Train set Size : {train_df.shape} ({len(train_df)/len(df):.1%})")
print(f"Test set Size : {test_df.shape} ({len(test_df)/len(df):.1%})")
print(f"Validation set Size : {val_df.shape} ({len(val_df)/len(df):.1%})")
# Out:
# Train set Size : (67530, 16) (70.0%)
# Test set Size : (14472, 16) (15.0%)
# Validation set Size : (14474, 16) (15.0%)

# %%
train_ratio = train_df["is_late"].mean() * 100  # حساب المتوسط الحسابي للعمود الذي يدل على حالة الطلبات   التأخرة او نسبة الطلبات المتأخرة في هذه المجموعة 
val_ratio = val_df["is_late"].mean() * 100
test_ratio = test_df["is_late"].mean() * 100 

print(f"delay rate in Train set : {train_ratio:.2f}%)")
print(f"delay rate in Test set : {test_ratio:.2f}%")
print(f"delay rate in validation set : {val_ratio:.2f}%")

# النسب متقاربة من بعضها وهذا امر جيد
# Out:
# delay rate in Train set : 8.11%)
# delay rate in Test set : 8.11%
# delay rate in validation set : 8.11%

# %%
os.makedirs("artifacts", exist_ok=True)
train_df.to_csv("artifacts/train.csv",index=False)
test_df.to_csv("artifacts/test.csv",index=False)
val_df.to_csv("artifacts/val.csv",index=False)



print(f"Complete tran.csv  , test.csv  , val.csv  , To Save In Artifact")
# Out:
# Complete tran.csv  , test.csv  , val.csv  , To Save In Artifact
